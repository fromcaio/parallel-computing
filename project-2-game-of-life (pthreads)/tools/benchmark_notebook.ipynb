# %% [markdown]
# # 🧬 Conway's Game of Life: Analysis & Benchmarking
#
# This notebook provides a comprehensive analysis of Conway's Game of Life, featuring:
# 1. **Visualization**: A pure Python implementation to demonstrate specific patterns like the **Glider** and **Glider Gun**.
# 2. **Integration**: Wrappers to compile and run the optimized C implementations (Sequential & Pthreads).
# 3. **High-Performance Benchmarking**: Automated stress testing on high-core-count CPUs (Xeon 20-thread test).

# %%
import os
import sys
import re
import subprocess
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Setup plotting style
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

# --- WORKING DIRECTORY SETUP ---
if os.path.basename(os.getcwd()) == 'tools':
    os.chdir('..')
    print(f"Moved working directory to project root: {os.getcwd()}")
else:
    print(f"Current working directory: {os.getcwd()}")

# Define paths
BIN_DIR = "bin"
SAMPLES_DIR = "samples"
SEQ_EXE = os.path.join(BIN_DIR, "game_of_life_seq")
PAR_EXE = os.path.join(BIN_DIR, "game_of_life_pthread")

os.makedirs(SAMPLES_DIR, exist_ok=True)
# Out:
# Moved working directory to project root: /home/fc/Documents/github/parallel-computing/project-2-game-of-life-pthreads

# %% [markdown]
# ## 1️⃣ Part 1: Visualizing the Logic
#
# We use a pure Python implementation to verify the rules and visualize standard patterns.

# %%
def python_step(grid):
    """
    Pure Python/NumPy implementation of one Game of Life step.
    Uses circular boundary conditions (toroidal) via np.roll.
    """
    neighbors = (
        np.roll(grid, 1, 0) + np.roll(grid, -1, 0) +
        np.roll(grid, 1, 1) + np.roll(grid, -1, 1) +
        np.roll(np.roll(grid, 1, 0), 1, 1) +
        np.roll(np.roll(grid, 1, 0), -1, 1) +
        np.roll(np.roll(grid, -1, 0), 1, 1) +
        np.roll(np.roll(grid, -1, 0), -1, 1)
    )
    
    new_grid = np.zeros_like(grid)
    new_grid[(grid == 1) & ((neighbors == 2) | (neighbors == 3))] = 1
    new_grid[(grid == 0) & (neighbors == 3)] = 1
    return new_grid

def create_glider(rows=10, cols=10):
    """Creates a grid with a single Glider at the top-left."""
    grid = np.zeros((rows, cols), dtype=int)
    # Standard Glider pattern
    coords = [(0,1), (1,2), (2,0), (2,1), (2,2)]
    for r, c in coords:
        grid[r, c] = 1
    return grid

def create_gun(rows=50, cols=50):
    """Creates a grid with a Gosper Glider Gun."""
    grid = np.zeros((rows, cols), dtype=int)
    gun_coords = [
        (5,1),(5,2),(6,1),(6,2),
        (3,13),(3,14),(4,12),(4,16),(5,11),(5,17),(6,11),(6,15),(6,17),(6,18),
        (7,11),(7,17),(8,12),(8,16),(9,13),(9,14),
        (1,25),(2,23),(2,25),(3,21),(3,22),(4,21),(4,22),(5,21),(5,22),
        (6,23),(6,25),(7,25),
        (3,35),(3,36),(4,35),(4,36)
    ]
    for r, c in gun_coords:
        if r < rows and c < cols:
            grid[r, c] = 1
    return grid

# %% [markdown]
# ### **Visualizing the Glider Pattern**
#
# A **Glider** is the smallest and most common "spaceship" in the Game of Life. It consists of 5 live cells that oscillate through 4 distinct phases.
#
# **Behavior:**
# * It travels diagonally across the grid.
# * It repeats its shape every 4 generations, shifted by one cell diagonally.
# * Below, we observe the cycle from **Generation 0** to **Generation 8** (two full cycles).
# * *Note: Grid lines have been added to make the cell movement easier to track.*

# %%
# Setup Glider Grid
rows, cols = 8, 8
glider_grid = create_glider(rows, cols)

fig, axes = plt.subplots(3, 3, figsize=(10, 10))
plt.subplots_adjust(wspace=0.3, hspace=0.3)
axes = axes.flatten()

cmap = ListedColormap(['#ffffff', '#2c3e50'])  # White background, dark cells

# Simulate and Plot 9 frames (Gen 0 to Gen 8)
current = glider_grid.copy()
for i, ax in enumerate(axes):
    # Plot current state
    ax.imshow(current, cmap=cmap, interpolation='nearest', vmin=0, vmax=1)
    ax.set_title(f"Generation {i}", fontweight='bold')
    
    # Add explicit gridlines for clarity
    ax.set_xticks(np.arange(-.5, cols, 1))
    ax.set_yticks(np.arange(-.5, rows, 1))
    ax.grid(color='gray', linestyle='-', linewidth=1)
    ax.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
    
    # Step forward
    current = python_step(current)

plt.suptitle("Glider Evolution (Gen 0-8)", fontsize=16)
plt.show()

# %% [markdown]
# ### **Visualizing Complex Patterns (Gosper Glider Gun)**
#
# The Glider Gun is a pattern that periodically produces gliders.

# %%
rows, cols = 40, 40
gun_grid = create_gun(rows, cols)

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
cmap = ListedColormap(['#f0f0f0', '#2c3e50'])

checkpoints = [0, 30, 60]
current = gun_grid.copy()
current_gen = 0

for ax, target_gen in zip(axes, checkpoints):
    # Advance to target generation
    while current_gen < target_gen:
        current = python_step(current)
        current_gen += 1
        
    ax.imshow(current, cmap=cmap, interpolation='nearest')
    ax.set_title(f"Generation {target_gen}")
    ax.grid(False)
    ax.axis('off')

plt.suptitle("Gosper Glider Gun Timeline", fontsize=16)
plt.show()

# %% [markdown]
# ## 2️⃣ Part 2: C Compilation
#
# Compiling the project to ensure binaries are fresh.

# %%
print("🔨 Compiling C project...")
try:
    subprocess.run(["make", "clean"], check=True, stdout=subprocess.DEVNULL)
    subprocess.run(["make", "sequential"], check=True, stdout=subprocess.PIPE)
    subprocess.run(["make", "parallel"], check=True, stdout=subprocess.PIPE)
    print("✅ Build successful.")
except subprocess.CalledProcessError as e:
    print(f"❌ Compilation failed: {e}")
# Out:
# 🔨 Compiling C project...
# ✅ Build successful.

# %%
# Benchmark Helpers
def parse_c_output(stdout_str):
    time_match = re.search(r"Execution time:\s+([0-9\.]+)\s+seconds", stdout_str)
    mem_match = re.search(r"Peak memory:\s+([0-9]+)\s+KB", stdout_str)
    return (float(time_match.group(1)) if time_match else None, 
            int(mem_match.group(1)) if mem_match else None)

def generate_input_file(filename, rows, cols, generations, density=0.2):
    filepath = os.path.join(SAMPLES_DIR, filename)
    total = rows * cols
    alive = int(total * density)
    rng = np.random.default_rng()
    indices = rng.choice(total, alive, replace=False)
    rows_idx, cols_idx = np.unravel_index(indices, (rows, cols))
    
    with open(filepath, 'w') as f:
        f.write(f"{generations}\n{rows} {cols}\n{alive}\n")
        for r, c in zip(rows_idx, cols_idx):
            f.write(f"{r} {c}\n")
    return filepath

def run_benchmark(executable, input_file, threads=None):
    cmd = [executable, input_file]
    if threads: cmd.append(str(threads))
    try:
        res = subprocess.run(cmd, capture_output=True, text=True, check=True)
        return parse_c_output(res.stdout)
    except: return None, None

# %% [markdown]
# ## 3️⃣ Part 3: High-Thread Benchmarking (Xeon Scale)
#
# We configured the test for a **10-core / 20-thread Xeon** processor.
#
# **Thread Strategy:**
# * **1-10 Threads:** Testing scaling within physical cores.
# * **11-20 Threads:** Testing SMT (Hyperthreading) efficiency.
# * **21-40 Threads:** Testing oversubscription/context-switching overhead.
#
# **Grid Sizes:** 1000, 2000, 4000, 5000

# %%
# --- HIGH THREAD CONFIGURATION ---
GRID_SIZES = [1000, 2000, 4000, 5000]
THREAD_COUNTS = [1, 2, 4, 8, 10, 16, 20, 32, 40]
GENERATIONS = 50
DENSITY = 0.2

results = []
print(f"🚀 Starting High-Thread Benchmark (Generations: {GENERATIONS})...")
print(f"{'Size':<8} | {'Type':<6} | {'Threads':<8} | {'Time (s)':<10} | {'Mem (MB)':<10}")
print("-" * 55)

for size in GRID_SIZES:
    fname = f"bench_xeon_{size}x{size}.txt"
    input_path = generate_input_file(fname, size, size, GENERATIONS, DENSITY)
    
    # Baseline Sequential
    seq_time, seq_mem = run_benchmark(SEQ_EXE, input_path)
    if seq_time:
        print(f"{size:<8} | {'Seq':<6} | {'1':<8} | {seq_time:<10.4f} | {seq_mem/1024:<10.1f}")
        results.append({'Size': size, 'Type': 'Sequential', 'Threads': 1, 
                        'Time': seq_time, 'Memory_MB': seq_mem/1024, 'Speedup': 1.0})
    
    # Threaded Runs
    for t in THREAD_COUNTS:
        par_time, par_mem = run_benchmark(PAR_EXE, input_path, threads=t)
        if par_time and seq_time:
            speedup = seq_time / par_time
            print(f"{size:<8} | {'Par':<6} | {t:<8} | {par_time:<10.4f} | {par_mem/1024:<10.1f}")
            results.append({'Size': size, 'Type': 'Parallel', 'Threads': t, 
                            'Time': par_time, 'Memory_MB': par_mem/1024, 'Speedup': speedup})

df = pd.DataFrame(results)
# Out:
# 🚀 Starting High-Thread Benchmark (Generations: 50)...
# Size     | Type   | Threads  | Time (s)   | Mem (MB)
# -------------------------------------------------------
# 1000     | Seq    | 1        | 4.3729     | 156.3
# 1000     | Par    | 1        | 4.4503     | 156.3
# 1000     | Par    | 2        | 2.3485     | 156.3
# 1000     | Par    | 4        | 1.2169     | 156.3
# 1000     | Par    | 8        | 0.6989     | 156.3
# 1000     | Par    | 10       | 0.6355     | 156.3
# 1000     | Par    | 16       | 0.6339     | 156.3
# 1000     | Par    | 20       | 0.5534     | 156.3
# 1000     | Par    | 32       | 0.5341     | 156.3
# 1000     | Par    | 40       | 0.5288     | 156.3
# 2000     | Seq    | 1        | 17.1291    | 182.0
# 2000     | Par    | 1        | 17.1247    | 182.0
# 2000     | Par    | 2        | 8.9809     | 182.0
# 2000     | Par    | 4        | 4.5213     | 182.0
# 2000     | Par    | 8        | 2.4669     | 182.0
# 2000     | Par    | 10       | 2.0090     | 182.0
# 2000     | Par    | 16       | 2.2395     | 182.0
# 2000     | Par    | 20       | 1.9269     | 182.0
# 2000     | Par    | 32       | 1.9002     | 182.0
# 2000     | Par    | 40       | 1.8802     | 182.0
# 4000     | Seq    | 1        | 67.0564    | 292.0
# 4000     | Par    | 1        | 67.9109    | 292.0
# 4000     | Par    | 2        | 34.7600    | 292.0
# 4000     | Par    | 4        | 18.4131    | 292.0
# 4000     | Par    | 8        | 9.3044     | 292.0
# 4000     | Par    | 10       | 7.6400     | 292.0
# 4000     | Par    | 16       | 8.5427     | 292.0
# 4000     | Par    | 20       | 7.5020     | 292.0
# 4000     | Par    | 32       | 7.8531     | 292.0
# 4000     | Par    | 40       | 7.5150     | 292.0
# 5000     | Seq    | 1        | 100.3386   | 398.9
# 5000     | Par    | 1        | 104.3410   | 398.9
# 5000     | Par    | 2        | 54.6178    | 398.9
# 5000     | Par    | 4        | 28.4175    | 398.9
# 5000     | Par    | 8        | 14.3407    | 398.9
# 5000     | Par    | 10       | 11.8350    | 398.9
# 5000     | Par    | 16       | 13.3089    | 398.9
# 5000     | Par    | 20       | 11.3357    | 398.9
# 5000     | Par    | 32       | 11.6637    | 398.9
# 5000     | Par    | 40       | 11.3941    | 398.9

# %%
# --- XEON SCALING PLOT ---
plt.figure(figsize=(12, 6))
par_df = df[df["Type"] == "Parallel"]

for size in GRID_SIZES:
    subset = par_df[par_df["Size"] == size]
    plt.plot(subset["Threads"], subset["Speedup"], marker='o', linewidth=2, label=f"{size}x{size} Grid")

# Reference Lines
plt.axvline(x=10, color='r', linestyle='--', alpha=0.5, label="Physical Cores (10)")
plt.axvline(x=20, color='g', linestyle='--', alpha=0.5, label="SMT Limit (20)")
plt.plot(THREAD_COUNTS, THREAD_COUNTS, '--', color='gray', alpha=0.3, label="Ideal Speedup")

plt.title("Xeon Scalability: Speedup vs Thread Count")
plt.xlabel("Threads")
plt.ylabel("Speedup")
plt.legend()
plt.xticks(THREAD_COUNTS)
plt.show()

# %%
# Display a clean summary table sorted by Size and Efficiency
summary = df[['Size', 'Type', 'Threads', 'Time', 'Speedup', 'Memory_MB']].sort_values(['Size', 'Threads'])
summary.style.background_gradient(subset=['Speedup'], cmap='Greens').format({
    'Time': '{:.4f}',
    'Speedup': '{:.2f}',
    'Memory_MB': '{:.1f}'
})
# Out:
# <style type="text/css">
# #T_ea8ea_row0_col4, #T_ea8ea_row10_col4, #T_ea8ea_row11_col4, #T_ea8ea_row20_col4, #T_ea8ea_row30_col4 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_ea8ea_row1_col4, #T_ea8ea_row21_col4, #T_ea8ea_row31_col4 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_ea8ea_row2_col4 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_ea8ea_row3_col4 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_ea8ea_row4_col4 {
#   background-color: #3ba458;
#   color: #f1f1f1;
# }
# #T_ea8ea_row5_col4 {
#   background-color: #29914a;
#   color: #f1f1f1;
# }
# #T_ea8ea_row6_col4 {
#   background-color: #289049;
#   color: #f1f1f1;
# }
# #T_ea8ea_row7_col4 {
#   background-color: #067230;
#   color: #f1f1f1;
# }
# #T_ea8ea_row8_col4 {
#   background-color: #00682a;
#   color: #f1f1f1;
# }
# #T_ea8ea_row9_col4 {
#   background-color: #006529;
#   color: #f1f1f1;
# }
# #T_ea8ea_row12_col4 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_ea8ea_row13_col4 {
#   background-color: #aadda4;
#   color: #000000;
# }
# #T_ea8ea_row14_col4 {
#   background-color: #278f48;
#   color: #f1f1f1;
# }
# #T_ea8ea_row15_col4 {
#   background-color: #005b25;
#   color: #f1f1f1;
# }
# #T_ea8ea_row16_col4 {
#   background-color: #0e7936;
#   color: #f1f1f1;
# }
# #T_ea8ea_row17_col4 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_ea8ea_row18_col4 {
#   background-color: #00481d;
#   color: #f1f1f1;
# }
# #T_ea8ea_row19_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_ea8ea_row22_col4 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_ea8ea_row23_col4 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# #T_ea8ea_row24_col4 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_ea8ea_row25_col4 {
#   background-color: #005120;
#   color: #f1f1f1;
# }
# #T_ea8ea_row26_col4 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_ea8ea_row27_col4, #T_ea8ea_row29_col4 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_ea8ea_row28_col4 {
#   background-color: #005a24;
#   color: #f1f1f1;
# }
# #T_ea8ea_row32_col4 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_ea8ea_row33_col4 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_ea8ea_row34_col4 {
#   background-color: #258d47;
#   color: #f1f1f1;
# }
# #T_ea8ea_row35_col4 {
#   background-color: #005c25;
#   color: #f1f1f1;
# }
# #T_ea8ea_row36_col4 {
#   background-color: #137d39;
#   color: #f1f1f1;
# }
# #T_ea8ea_row37_col4 {
#   background-color: #004e1f;
#   color: #f1f1f1;
# }
# #T_ea8ea_row38_col4 {
#   background-color: #005723;
#   color: #f1f1f1;
# }
# #T_ea8ea_row39_col4 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ea8ea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea8ea_level0_col0" class="col_heading level0 col0" >Size</th>
#       <th id="T_ea8ea_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_ea8ea_level0_col2" class="col_heading level0 col2" >Threads</th>
#       <th id="T_ea8ea_level0_col3" class="col_heading level0 col3" >Time</th>
#       <th id="T_ea8ea_level0_col4" class="col_heading level0 col4" >Speedup</th>
#       <th id="T_ea8ea_level0_col5" class="col_heading level0 col5" >Memory_MB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea8ea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea8ea_row0_col0" class="data row0 col0" >1000</td>
#       <td id="T_ea8ea_row0_col1" class="data row0 col1" >Sequential</td>
#       <td id="T_ea8ea_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_ea8ea_row0_col3" class="data row0 col3" >4.3729</td>
#       <td id="T_ea8ea_row0_col4" class="data row0 col4" >1.00</td>
#       <td id="T_ea8ea_row0_col5" class="data row0 col5" >156.3</td>
#     </tr>
#     <tr>
#       <th id="T_ea8ea_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ea8ea_row1_col0" class="data row1 col0" >1000</td>
#       <td id="T_ea8ea_row1_col1" class="data row1 col1" >Parallel</td>
#       <td id="T_ea8ea_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_ea8ea_row1_col3" class="data row1 col3" >4.4503</td>
#       <td id="T_ea8ea_row1_col4" class="data row1 col4" >0.98</td>
#       <td id="T_ea8ea_row1_col5" class="data row1 col5" >156.3</td>
#     </tr>
#     <tr>
#       <th id="T_ea8ea_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ea8ea_row2_col0" class="data row2 col0" >1000</td>
#       <td id="T_ea8ea_row2_col1" class="data row2 col1" >Parallel</td>
#       <td id="T_ea8ea_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_ea8ea_row2_col3" class="data row2 col3" >2.3485</td>
#       <td id="T_ea8ea_row2_col4" class="data row2 col4" >1.86</td>
#       <td id="T_ea8ea_row2_col5" class="data row2 col5" >156.3</td>
#     </tr>
#     <tr>
#       <th id="T_ea8ea_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ea8ea_row3_col0" class="data row3 col0" >1000</td>
#       <td id="T_ea8ea_row3_col1" class="data row3 col1" >Parallel</td>
#       <td id="T_ea8ea_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_ea8ea_row3_col3" class="data row3 col3" >1.2169</td>
#       <td id="T_ea8ea_row3_col4" class="data row3 col4" >3.59</td>
#       <td id="T_ea8ea_row3_col5" class="data row3 col5" >156.3</td>
#     </tr>
#     <tr>
#       <th id="T_ea8ea_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ea8ea_row4_col0" class="data row4 col0" >1000</td>
#       <td id="T_ea8ea_row4_col1" class="data row4 col1" >Parallel</td>
#       <td id="T_ea8ea_row4_col2" class="data row4 col2" >8</td>
#       <td id="T_ea8ea_row4_col3" class="data row4 col3" >0.6989</td>
#       <td id="T_ea8ea_row4_col4" class="data row4 col4" >6.26</td>
#       <td id="T_ea8ea_row4_col5" class="data row4 col5" >156.3</td>
#     </tr>
#     <tr>
#       <th id="T_ea8ea_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ea8ea_row5_col0" class="data row5 col0" >1000</td>
#       <td id="T_ea8ea_row5_col1" class="data row5 col1" >Parallel</td>
#       <td id="T_ea8ea_row5_col2" class="data row5 col2" >10</td>
#       <td id="T_ea8ea_row5_col3" class="data row5 col3" >0.6355</td>
#       <td id="T_ea8ea_row5_col4" class="data row5 col4" >6.88</td>
#       <td id="T_ea8ea_row5_col5" class="data row5 col5" >156.3</td>
#     </tr>
#     <tr>
#       <th id="T_ea8ea_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ea8ea_row6_col0" class="data row6 col0" >1000</td>
#       <td id="T_ea8ea_row6_col1" class="data row6 col1" >Parallel</td>
#       <td id="T_ea8ea_row6_col2" class="data row6 col2" >16</td>
#       <td id="T_ea8ea_row6_col3" class="data row6 col3" >0.6339</td>
#       <td id="T_ea8ea_row6_col4" class="data row6 col4" >6.90</td>
#       <td id="T_ea8ea_row6_col5" class="data row6 col5" >156.3</td>
#     </tr>
#     <tr>
#       <th id="T_ea8ea_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ea8ea_row7_col0" class="data row7 col0" >1000</td>
#       <td id="T_ea8ea_row7_col1" class="data row7 col1" >Parallel</td>
#       <td id="T_ea8ea_row7_col2" class="data row7 col2" >20</td>
#       <td id="T_ea8ea_row7_col3" class="data row7 col3" >0.5534</td>
#       <td id="T_ea8ea_row7_col4" class="data row7 col4" >7.90</td>
#       <td id="T_ea8ea_row7_col5" class="data row7 col5" >156.3</td>
#     </tr>
#     <tr>
#       <th id="T_ea8ea_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ea8ea_row8_col0" class="data row8 col0" >1000</td>
#       <td id="T_ea8ea_row8_col1" class="data row8 col1" >Parallel</td>
#       <td id="T_ea8ea_row8_col2" class="data row8 col2" >32</td>
#       <td id="T_ea8ea_row8_col3" class="data row8 col3" >0.5341</td>
#       <td id="T_ea8ea_row8_col4" class="data row8 col4" >8.19</td>
#       <td id="T_ea8ea_row8_col5" class="data row8 col5" >156.3</td>
#     </tr>
#     <tr>
#       <th id="T_ea8ea_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ea8ea_row9_col0" class="data row9 col0" >1000</td>
#       <td id="T_ea8ea_row9_col1" class="data row9 col1" >Parallel</td>
#       <td id="T_ea8ea_row9_col2" class="data row9 col2" >40</td>
#       <td id="T_ea8ea_row9_col3" class="data row9 col3" >0.5288</td>
#       <td id="T_ea8ea_row9_col4
